# %% [markdown]
# ## Task 2

# %%
#Reading and Writing from a file.
#reading a file
f1 = open("/content/File1.txt",'r')
print(f1.read())
# Out:
# This is the first file .
# Python is a powerful language with easy syntax
# Coding improves mental health .
# Reminder to drink water.

# %%
f1.close()

# %%
#writing the contents of a file
f2 = open("/content/sample_text1.txt", 'r')
print(f2.read())
# Out:
# I will now make changes in the contents of the file/n

# %%
f2.close()

# %%
f2 = open("/content/sample_text1.txt", 'w')

# %%
f2.write('I will now make changes in the contents of the file/n',)
f2.close()

# %%
f2 = open("/content/sample_text1.txt", 'r')

# %%
print(f2.read())
# Out:
# I will now make changes in the contents of the file/n

# %%
f2.close()

# %%
# to find out the file size
import os

# %%
file_name ="/content/sample_text2.txt"

file_stats = os.stat(file_name)

print(file_stats)
print(f'File Size in Bytes is {file_stats.st_size}')
# Out:
# os.stat_result(st_mode=33188, st_ino=1835023, st_dev=51, st_nlink=1, st_uid=0, st_gid=0, st_size=100, st_atime=1711775999, st_mtime=1711775542, st_ctime=1711775542)
# File Size in Bytes is 100

# %%
#to find out the most frequent word

# %%
from collections import Counter
with open("/content/sample_text2.txt", 'r') as file_1:
   text = file_1.read().lower()
   words = text.split()
   word_counts = Counter(words)
   most_common_word, frequency = word_counts.most_common(1)[0]
print(f"The most frequent word is '{most_common_word}' with frequency {frequency}.")
file_1.close()
# Out:
# The most frequent word is 'python' with frequency 5.

# %%
# to get a specific line from a file

# %%
file1=open("/content/sample_text2.txt","r")
content=file1.readlines()
file1.close()
index=int(input("Enter the line number to read:"))
print(content[index-1])
# Out:
# Enter the line number to read:4
# python python python python

# %%
#loading a json file in python
import json

f = open('/content/sample.json')

data = json.load(f)

print(data)

f.close()

# %%
dictionary = {
    "name": "Harsh Martin Topno",
    "rollno": 2306187,
    "language": "Python"
}

with open("sample.json", "w") as outfile:
    json.dump(dictionary, outfile)

f = open('/content/sample.json')
data = json.load(f)

print(data)

f.close()
