# %% [markdown]
# To read the content from one file and write it in the other.

# %%
with open("/content/drive/MyDrive/Colab Notebooks/file1.txt","r") as readfile:
  with open("/content/drive/MyDrive/Colab Notebooks/file2.txt","w") as writefile:
    for line in readfile:
      a=writefile.write(line)

print("file a is read and written in b")
print(a)
# Out:
# file a is read and written in b
# 71

# %% [markdown]
#  check size of file in python.

# %%
myfile=open("/content/drive/MyDrive/Colab Notebooks/file1.txt","r")
str=myfile.read()
size=len(str)
print("size of the given file file1.txt is")
print(size, "bytes")
# Out:
# size of the given file file1.txt is
# 207 bytes

# %% [markdown]
# most repeated word in a text file.

# %%
with open("/content/drive/MyDrive/Colab Notebooks/file1.txt","r") as file1:
   words=file1.read().split() # split will split the txt. file into words.
dict={} # created dictionary where words will be stored.here key:value is word:no. of times it occured.
for a in words:
  if a in dict:
    dict[a]=dict[a]+1
  else:
    dict[a]=1
max_time_word=None
max_count=0
for a, count in dict.items():
  if count>max_count:
    max_count=count
    max_time_word=a
print("the most repeated word is", max_time_word)
print("it appears",max_count,"times")
# Out:
# the most repeated word is files
# it appears 3 times

# %% [markdown]
# Read specific lines from a file in python.

# %%
file1=open("/content/drive/MyDrive/Colab Notebooks/file2.py")
content=file1.readlines()
print("third line is", content[2])
print("first three lines", content[0:3])
# Out:
# third line is a=30
#
# first three lines ['print("hello world")\n', 'print("hey there I am using python")\n', 'a=30\n']

# %% [markdown]
# write a dictionary to a file in python

# %%
dict={'key1':'value1', 'key2':'value2','key3':'value3'}
with open("/content/drive/MyDrive/Colab Notebooks/file1.py","w") as file:
    for key, value in dict.items():
      file.write(f"{key}: {value}\n")
